# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %%
#caricamento file excel (lettura lenta -> conversione in csv)
file_path = '/content/drive/MyDrive/globalterrorismdb_0522dist.xlsx'


df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#converisone csv
df.to_csv("df.csv", index=False)

# %%
#verifica del dataset e della correttezza dei dati
file_path1 = '/content/drive/MyDrive/GTD.csv'

df1 = pd.read_csv(file_path1)
# Out:
# /tmp/ipython-input-327460695.py:4: DtypeWarning: Columns (4,31,33,54,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(file_path1)

# %%
df_italy = df1[df1['country_txt'] == 'Italy']

# %%
df_tuscany=df_italy[df_italy['provstate'] == 'Tuscany']
df_tuscany
# Out:
# ...
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1709    197301170001   1973       1    17        NaN         0        NaN
# 2606    197410220002   1974      10    22        NaN         0        NaN
# 2661    197411160001   1974      11    16        NaN         0        NaN
# 3720    197604140002   1976       4    14        NaN         0        NaN
# 3727    197604170001   1976       4    17        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 133290  201406100083   2014       6    10        NaN         0        NaN
# 141922  201412210068   2014      12    21        NaN         0        NaN
# 171520  201701010006   2017       1     1        NaN         0        NaN
# 188914  201808020044   2018       8     2        NaN         0        NaN
# 197893  201907220009   2019       7    22        NaN         0        NaN
#
#         country country_txt  region      region_txt provstate       city  \
# ...

# %%
df1.head(26)
# Out:
#          eventid  iyear  imonth  iday           approxdate  extended  \
# 0   197000000001   1970       7     2                  NaN         0
# 1   197000000002   1970       0     0                  NaN         0
# 2   197001000001   1970       1     0                  NaN         0
# 3   197001000002   1970       1     0                  NaN         0
# 4   197001000003   1970       1     0                  NaN         0
# 5   197001010002   1970       1     1                  NaN         0
# 6   197001020001   1970       1     2                  NaN         0
# 7   197001020002   1970       1     2                  NaN         0
# 8   197001020003   1970       1     2                  NaN         0
# 9   197001030001   1970       1     3                  NaN         0
# 10  197001050001   1970       1     1                  NaN         0
# 11  197001060001   1970       1     6                  NaN         0
# 12  197001080001   1970       1     8                  NaN         0
# ...

# %%
#filtro per anno dal 2017 in poi
df_2018_2020 = df1[df1['iyear'] > 2017]

# %%
df_2018_2020.to_csv("GTD_2018-2020.csv", index=False)

# %%
#-------------------------

# %%
#stesso processo per i dati del 2021

file_path2 = '/content/drive/MyDrive/globalterrorismdb_2021Jan-June_1222dist.xlsx'


df2 = pd.read_excel(file_path2)


df2.to_csv("GTD2.csv", index=False)

# %%
#-------------------------

# %%
#join  tra i dati del 2018-2020 + 2021

# Carica il primo dataset (filtrato con anno > 2017)
df_1= pd.read_csv("/content/drive/MyDrive/GTD_2018-2020.csv", low_memory=False)

# Carica il secondo dataset
df_2 = pd.read_csv("/content/drive/MyDrive/GTD_2021.csv", low_memory=False)

# Unisci i due dataset (uno sotto l'altro)
df_unito = pd.concat([df_1, df_2], ignore_index=True)

# Mostra qualche riga per verifica
print(df_unito.head())

# Salva il dataset unito
df_unito.to_csv("GTD_2018-2021.csv", index=False)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  201801010001   2018       1     1        NaN         0        NaN       95
# 1  201801010003   2018       1     1        NaN         0        NaN       95
# 2  201801010004   2018       1     1        NaN         0        NaN      153
# 3  201801010005   2018       1     1        NaN         0        NaN      153
# 4  201801010032   2018       1     1        NaN         0        NaN      147
#
#   country_txt  region  ...                                           addnotes  \
# 0        Iraq      10  ...                                                NaN
# 1        Iraq      10  ...                                                NaN
# 2    Pakistan       6  ...                                                NaN
# 3    Pakistan       6  ...                                                NaN
# 4     Nigeria      11  ...  Casualty numbers conflict across sources. Foll...
#
# ...

# %%
df_full= pd.read_csv("/content/GTD_2018-2021.csv")
# Out:
# /tmp/ipython-input-541798261.py:1: DtypeWarning: Columns (63,79,115) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full= pd.read_csv("/content/GTD_2018-2021.csv")

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31788 entries, 0 to 31787
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(23), object(56)
# memory usage: 32.7+ MB

# %%
df_1.shape + df_2.shape
# Out:
# (26828, 135, 4960, 135)

# %%
df_full.shape
# Out:
# (31788, 135)
